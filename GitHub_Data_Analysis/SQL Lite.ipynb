# %%
import pandas as pd

# %%
import sqlite3
conn = sqlite3.connect("Issues.db")

# %%
cur = conn.cursor()

# %%
from datetime import datetime
df=pd.DataFrame.from_csv('Sliced_Issues_from_2017-09-10_to_2017-09-19.csv')
df.to_sql("Issues_Table", conn, if_exists="replace")
# Out:
# /anaconda/envs/tensorenv-3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df_=pd.read_sql_query("select * from Issues_Table;", conn)

# %%
df_
# Out:
#          index     issue.id  \
# 0            0  256474258.0
# 1            1  256474264.0
# 2            2  256434757.0
# 3            3  256474270.0
# 4            4  256474274.0
# 5            5  256461838.0
# 6            6  256474276.0
# 7            7  201029135.0
# 8            8  256474278.0
# 9            9  238307137.0
# 10          10  256474287.0
# 11          11  256474289.0
# 12          12  256474292.0
# 13          13  256474293.0
# 14          14  256474299.0
# 15          15  252868117.0
# 16          16  256474303.0
# 17          17  256474312.0
# 18          18  256474313.0
# 19          19  256474312.0
# 20          20  256474313.0
# 21          21  256474318.0
# 22          22  256474320.0
# 23          23  256474321.0
# 24          24  256474325.0
# 25          25  256474185.0
# 26          26  256474332.0
# 27          27  240487386.0
# 28          28  256474333.0
# 29          29  256474336.0
# ...        ...          ...
# 410673  410669  258763720.0
# ...

# %%
from datetime import datetime
df_Comments=pd.DataFrame.from_csv('Sliced_IssueComments_from_2017-09-10_to_2017-09-19.csv')
df_Comments.to_sql("IssueComments_Table", conn, if_exists="replace")
# Out:
# /anaconda/envs/tensorenv-3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (1,3,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df_Comments_=pd.read_sql_query("select * from IssueComments_Table;", conn)

# %%
df_Comments_.head()
# Out:
#   index comment.id                                       comment.body  \
# 0     0  328310688  We have an admin_centre role [in relation boun...
# 1     1  328310691                                  Should I UX this?
# 2     2  328310690  I think I kinda understand where the communica...
# 3     3  328310696  made title and actions fixed to top. headings ...
# 4     4  328310697  Hey guys, I developed independently my version...
#
#     issue.id                                        issue.title   action  \
# 0  256404453   Render place names from both points and polygons  created
# 1  255610714  [2] Present an error message that disallows th...  created
# 2  256129892  WIP: [JVM] use num of Executors as nWorkers in...  created
# 3  256434757                         Make action buttons sticky  created
# 4  255403783                                        2.0 Rewrite  created
#
#   comment.user.id    comment.created_at    comment.updated_at  \
# ...

# %%
#Joining Issues and Isssue Comments

# %%
df.head()
# Out:
#       issue.id                                        issue.title  \
# 0  256474258.0                                   Project Feedback
# 1  256474264.0  get_io_context() deprecation makes ssl::stream...
# 2  256434757.0                         Make action buttons sticky
# 3  256474270.0                                        first title
# 4  256474274.0                     Contact page displayed weirdly
#
#                                           issue.body  action  issue.user.id  \
# 0  ## Build a résumé for a fictional character, a...  opened     11194027.0
# 1  The following code is impossible without using...  opened      1503976.0
# 2                                                NaN  closed     20607431.0
# 3                                  first description  opened     25985711.0
# 4                                                NaN  opened     30557998.0
#
#   issue.state issue.state.1 issue.locked  issue.assignee  issue.comments  \
# ...

# %%
df['duplicate_id']=df.duplicated(subset=['issue.id'])

df_duplicated=df[df['duplicate_id']==True]

# %%
#Getting a Small Sample of Issues
