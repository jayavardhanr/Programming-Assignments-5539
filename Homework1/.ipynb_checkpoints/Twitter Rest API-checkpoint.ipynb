# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# Import the necessary methods from "twitter" library
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# Variables that contains the user credentials to access Twitter API 
ACCESS_TOKEN = '900196035158573056-nnB6EWC8yYQ5SiTMfhZAbGbE2AqcQS0'
ACCESS_SECRET = '4USboHTuV1NtKIS877J409Vg6k5ux0BaWPTuuCdBk2cJK'
CONSUMER_KEY = 'tqneIAXvGS3ozwoAslVBAUo7v'
CONSUMER_SECRET = 'tqVQA2xuClZUfh9YSRzco00svzsYkBUgsLvLiXvkcD4UGzhZe9'

oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %%
# Initiate the connection to Twitter REST API
twitter = Twitter(auth=oauth)

# %%
twitter.search.tweets("places"=["country_code"="US"])
# Out:
#   File "<ipython-input-4-a148152ca31d>", line 2
#     twitter.search.tweets("places"=["country_code"="US"])
#                                                   ^
# SyntaxError: invalid syntax

# %%
result = twitter.geo.search(query="USA", granularity="country")
place_id = result['result']['places'][0]['id']

print(place_id)
# Out:
# 96683cc9126741d1

# %%
result = twitter.geo.search(query="US", granularity="country")
place_id = result['result']['places'][0]['id']

print(place_id)
# Out:
# 8f3fa3e2dedc1db5

# %%
result = twitter.geo.search(query="United States", granularity="country")
place_id = result['result']['places'][0]['id']

print(place_id)
# Out:
# 96683cc9126741d1

# %%
result = twitter.search.tweets(q="place:%s" % place_id)
print(result)
# Out:
# {u'search_metadata': {u'count': 15, u'completed_in': 0.08, u'max_id_str': u'904196238035312640', u'since_id_str': u'0', u'refresh_url': u'?since_id=904196238035312640&q=place%3A96683cc9126741d1&include_entities=1', u'since_id': 0, u'query': u'place%3A96683cc9126741d1', u'max_id': 904196238035312640}, u'statuses': [{u'contributors': None, u'truncated': False, u'text': u'@MikeyCummings Yes! Thank You! https://t.co/WF4tWDsHUY', u'is_quote_status': False, u'in_reply_to_status_id': 904138449246183424, u'id': 904196238035312640, u'favorite_count': 0, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 301027522, u'indices': [0, 14], u'id_str': u'301027522', u'screen_name': u'MikeyCummings', u'name': u'Mikey Cummings'}], u'hashtags': [], u'urls': [], u'media': [{u'expanded_url': u'https://twitter.com/BobbyLeeTN/status/904196238035312640/photo/1', u'display_url': u'pic.twitter.com/WF4tWDsHUY', u'url': u'https://t.co/WF4tWDsHUY', u'media_url_https': u'https://pbs.twimg.com/tweet_video_th
# ...

# %%
import pprint
pp=pprint.PrettyPrinter(indent=4)
pp.pprint(result)
# Out:
# {   u'search_metadata': {   u'completed_in': 0.08,
#                             u'count': 15,
#                             u'max_id': 904196238035312640,
#                             u'max_id_str': u'904196238035312640',
#                             u'query': u'place%3A96683cc9126741d1',
#                             u'refresh_url': u'?since_id=904196238035312640&q=place%3A96683cc9126741d1&include_entities=1',
#                             u'since_id': 0,
#                             u'since_id_str': u'0'},
#     u'statuses': [   {   u'contributors': None,
#                          u'coordinates': None,
#                          u'created_at': u'Sun Sep 03 04:15:56 +0000 2017',
#                          u'entities': {   u'hashtags': [],
#                                           u'media': [   {   u'display_url': u'pic.twitter.com/WF4tWDsHUY',
# ...

# %%
for tweet in result['statuses']:
    print tweet['text'] + " | " + tweet['place']['name'] if tweet['place'] else "Undefined place"
# Out:
# @MikeyCummings Yes! Thank You! https://t.co/WF4tWDsHUY | Brentwood
# You are my everything...😪 https://t.co/hjve0j7oni | Ventura
# I'm so sleepy | Detroit
# New season, same old shit. #Huskers | Bellevue
# Put a couch in the studio today it's lit | Los Angeles
# @Vada_Fly @ANGRYFAN007 Na bro they already got paid they could care less about who shows up they already got there money 😂 | Clinton
# There are some people in life that make you Laugh a little… https://t.co/510b1C4D8N | Tennessee
